# %% [markdown]
# # Dataset inspection
#
# 합법적으로 확보한 local JSON archive의 실제 key와 위치 값을 먼저 확인한다.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd() / "src"))
from ulm.data.aihub import audit_json_root

summary = audit_json_root(Path("/content/aihub_gyeongsang/json"))
summary.to_dict()
