# %% [markdown]
# # Base model baseline
#
# 학습 전 동일 prompt set의 출력을 저장한다. 결과는 `EXPERIMENTS.md`에 실제 실행 후 기록한다.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd() / "src"))
from ulm.inference.prompt import build_inference_messages

build_inference_messages("오늘 뭐 해?", dialect_strength=0)
