# %% [markdown]
# # Local inference
#
# 검증된 base/adapter를 사용해 `dialect_strength`를 지정한다. 임의 voice upload는 지원하지 않는다.

# %%
# !python scripts/infer.py \
  --model-name Qwen/Qwen3-0.6B \
  --text '오늘 뭐 해?' \
  --dialect-strength 2
