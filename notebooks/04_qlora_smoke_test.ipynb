# %% [markdown]
# # QLoRA smoke test
#
# 무료 GPU에서 5~20 step만 실행해 load → train → save → resume → eval 경로를 확인한다.

# %%
# !pip install -e '.[ml]'
# !python scripts/train_sft.py --config configs/sft/qwen3_0.6b_qlora.yaml

# %%
# !python scripts/train_sft.py --config configs/sft/qwen3_0.6b_qlora.yaml --dry-run
