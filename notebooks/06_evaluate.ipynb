# %% [markdown]
# # ULM-Bench 평가
#
# 실행 결과를 자동 metric으로 요약한다. fixture 점수는 연구 결과로 해석하지 않는다.

# %%
# !python scripts/evaluate_benchmark.py \
  --benchmark benchmarks/fixtures/sample_benchmark.jsonl \
  --predictions benchmarks/fixtures/sample_predictions.jsonl
